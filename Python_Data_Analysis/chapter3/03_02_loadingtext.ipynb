# %% [markdown]
# # 03_02: Loading Text Files

# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
# iterating over an open file yields its lines, one by one

words = []
for line in open('words.txt', 'r'):
    words.append(line)

# %%
len(words)
# Out:
# 235886

# %%
words[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
'Aaron\n'.strip()
# the new line is stripped away.
# Out:
# 'Aaron'

# %%
'Aaron\n'.strip().lower()
# stripping the entire string to lower case.
# Out:
# 'aaron'

# %%
words = []
for line in open('words.txt', 'r'):
    words.append(line.strip().lower())
# appending to the empty list a stripped and lower case for each line.

# %%
words[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
# Building a set is a good way of getting rid of duplicates. 
words = set()
for line in open('words.txt', 'r'):
    words.add(line.strip().lower())

# %%
# a set comprehension that collects stripped and lowercased lines...
words = {line.strip().lower() for line in open('words.txt', 'r')}

# %%
words
# Out:
# {'unguaranteed',
#  'negatory',
#  'acetabuliferous',
#  'beslash',
#  'unwinking',
#  'mastoscirrhus',
#  'mendelian',
#  'schooltide',
#  'agitatorial',
#  'caselessly',
#  'winy',
#  'prosneusis',
#  'swapping',
#  'infrequently',
#  'noncontentious',
#  'autopsychic',
#  'pudge',
#  'terebratula',
#  'parallelly',
#  'violently',
#  'gillflirt',
#  'unanswerableness',
#  'chiefly',
#  'kefir',
#  'mustify',
#  'hillsalesman',
#  'disaffectation',
#  'analeptic',
#  'magneoptic',
#  'decarbonate',
#  'pulmometry',
#  'goliardery',
#  'hent',
#  'proprietous',
#  'semileafless',
#  'outjetting',
#  'synergistical',
#  'uptrail',
#  'wheelwright',
#  'orthoceratoid',
#  'anatomic',
#  'clabber',
#  'omnipregnant',
#  'contrabandery',
#  'searchableness',
#  'siphonata',
#  'praetor',
#  'staggerwort',
#  'urman',
#  'plaidie',
#  'muscleless',
#  'juramentado',
#  'unlanguid',
#  'absolvitory',
#  'fourierist',
#  'weatherly',
#  'triquinate',
#  'harpalus',
#  'stercophagic',
#  'plagal',
#  'surveyorship',
#  'sitotoxism',
#  'laity',
#  'therewithal',
#  'diplobacillus',
#  'loranskite',
#  'concomitant',
#  'horseweed',
#  'bewilderment',
#  'superimpersonal',
#  'unassuming',
#  'chimeric',
#  'cresswort',
#  'oleacina',
#  'archipallium',
#  'lubberliness',
#  'equalization',
#  'imperformable',
#  'fargood',
#  'keratinous',
#  'supersensuousness',
#  'xanthene',
#  'misplant',
#  'agnoite',
#  'shone',
#  'unhorse',
#  'rabbinship',
#  'alluviation',
#  'cottidae',
#  'parallelogrammatic',
#  'metaphorically',
#  'skeptic',
#  'enterology',
#  'lixivious',
#  'semiacidified',
#  'pennated',
#  'solenium',
#  'valued',
#  'wankliness',
#  'palative',
#  'bawn',
#  'ringingly',
#  'coaggregated',
#  'polymyodi',
#  'ananta',
#  'boutonniere',
#  'tuth',
#  'dramatical',
#  'grapeskin',
#  'overriches',
#  'synaxar',
#  'unbeast',
#  'nietzscheanism',
#  'arctomys',
#  'odontostomatous',
#  'unpostered',
#  'senility',
#  'unreckingness',
#  'markab',
#  'aleuritic',
#  'equisonance',
#  'mitogenetic',
#  'ranunculi',
#  'elongated',
#  'proballoon',
#  'errorist',
#  'brachering',
#  'beamlike',
#  'kinetogram',
#  'podarge',
#  'unextravasated',
#  'consul',
#  'countertime',
#  'polluted',
#  'strait',
#  'auricularis',
#  'korona',
#  'anthracyl',
#  'potency',
#  'sophiology',
#  'thoracectomy',
#  'notungulata',
#  'unseared',
#  'adulate',
#  'cassidony',
#  'exceptive',
#  'gallanilide',
#  'bodkin',
#  'dadap',
#  'idoneity',
#  'osteosynthesis',
#  'pseudopsychological',
#  'adendritic',
#  'inaccordancy',
#  'scissors',
#  'hypoionian',
#  'enterosyphilis',
#  'undecimole',
#  'endosarc',
#  'crankpin',
#  'unnoticing',
#  'batholite',
#  'supercritic',
#  'undecently',
#  'uniteable',
#  'recubant',
#  'unnative',
#  'tamanaco',
#  'spectatordom',
#  'worry',
#  'amylan',
#  'interpectoral',
#  'tittymouse',
#  'schistosomus',
#  'sinuatrial',
#  'theocrat',
#  'troupial',
#  'subtle',
#  'symmachy',
#  'untestable',
#  'pericholangitis',
#  'jobholder',
#  'lotrite',
#  'actine',
#  'gastropexy',
#  'infraterritorial',
#  'misintelligible',
#  'ventripotency',
#  'podocarpaceae',
#  'yamato',
#  'dehydrase',
#  'pigface',
#  'tarrass',
#  'pimenton',
#  'suranal',
#  'kvass',
#  'womanship',
#  'mucluc',
#  'authoritativeness',
#  'lienomalacia',
#  'pantalgia',
#  'gonotheca',
#  'sigillarian',
#  'slanginess',
#  'spectered',
#  'subarchitect',
#  'kilah',
#  'malleinization',
#  'pneumonorrhaphy',
#  'subjugate',
#  'fiefdom',
#  'groaning',
#  'beambird',
#  'gangism',
#  'halidom',
#  'orpharion',
#  'booking',
#  'periosteophyte',
#  'recordership',
#  'unbetray',
#  'insusceptibly',
#  'subsilicic',
#  'cocentric',
#  'reformability',
#  'thralldom',
#  'iberi',
#  'glabrescent',
#  'ovicyst',
#  'allodelphite',
#  'concubinarian',
#  'francophobe',
#  'overfastidious',
#  'tayassu',
#  'cardiomotility',
#  'urheen',
#  'ceil',
#  'kossean',
#  'ondogram',
#  'carina',
#  'thwartman',
#  'surrealist',
#  'paduanism',
#  'japanolatry',
#  'arsonic',
#  'miliarensis',
#  'progressivism',
#  'rootle',
#  'firefang',
#  'arsyl',
#  'reimbursement',
#  'serigraphy',
#  'symphysy',
#  'ovariocentesis',
#  'quivery',
#  'mannonic',
#  'pale',
#  'vicinage',
#  'neckband',
#  'warrand',
#  'flogger',
#  'khanum',
#  'minute',
#  'woald',
#  'tiddle',
#  'ageustia',
#  'intercooling',
#  'pirrmaw',
#  'cytosome',
#  'slatch',
#  'tibiocalcanean',
#  'zeoscope',
#  'beneficiaryship',
#  'grece',
#  'photoimpression',
#  'footprint',
#  'culpatory',
#  'monetize',
#  'amortization',
#  'noncarnivorous',
#  'pearl',
#  'splenocleisis',
#  'overtechnicality',
#  'fulgorous',
#  'nonidolatrous',
#  'pantastomatida',
#  'exorbitance',
#  'noyade',
#  'conjointness',
#  'unhaggled',
#  'micrampelis',
#  'otiatric',
#  'criticasterism',
#  'minimally',
#  'nettling',
#  'rhombogenous',
#  'teamsman',
#  'papize',
#  'sporocyst',
#  'curvate',
#  'sulfadiazine',
#  'becivet',
#  'psidium',
#  'kenspeckle',
#  'sterigma',
#  'apoatropine',
#  'overready',
#  'subregular',
#  'inimicality',
#  'godhead',
#  'masaris',
#  'thiostannic',
#  'almemar',
#  'fiberize',
#  'cytoryctes',
#  'threadmaking',
#  'tootle',
#  'cuminyl',
#  'bronchocavernous',
#  'metalepsis',
#  'certify',
#  'roridulaceae',
#  'somnambulically',
#  'speciality',
#  'stilton',
#  'wellman',
#  'taxlessness',
#  'corvillosum',
#  'doveflower',
#  'krameriaceae',
#  'misbaptize',
#  'hyotherium',
#  'unsped',
#  'ziphiidae',
#  'quartern',
#  'hurrisome',
#  'utriculate',
#  'kerel',
#  'prefamiliarity',
#  'collinal',
#  'serpentis',
#  'kittly',
#  'mobocratical',
#  'dividedness',
#  'kerry',
#  'skeeling',
#  'snubbish',
#  'tanguile',
#  'hederiferous',
#  'tampoon',
#  'tigelle',
#  'untransfused',
#  'springy',
#  'campodeoid',
#  'gluttonously',
#  'plumify',
#  'blebby',
#  'swith',
#  'indissoluble',
#  'escapade',
#  'tortoise',
#  'undersphere',
#  'inequitableness',
#  'kittle',
#  'undertrodden',
#  'opposit',
#  'hooven',
#  'sowback',
#  'scirpus',
#  'cheirolin',
#  'untill',
#  'aspirant',
#  'dioeciodimorphous',
#  'unstrap',
#  'unforbiddenly',
#  'pima',
#  'cussedness',
#  'nighness',
#  'unvenged',
#  'endodontia',
#  'mele',
#  'unmind',
#  'eclogite',
#  'biolytic',
#  'technopsychology',
#  'zoonosologist',
#  'protarsal',
#  'pampre',
#  'konia',
#  'dalton',
#  'hypozeuxis',
#  'madiga',
#  'perobrachius',
#  'causticization',
#  'ratcatcher',
#  'mignon',
#  'seagoing',
#  'anidiomatical',
#  'eulima',
#  'leopoldinia',
#  'unionize',
#  'unmapped',
#  'strepitantly',
#  'isobare',
#  'archaeolith',
#  'palaeotropical',
#  'styloglossus',
#  'tocororo',
#  'mattboard',
#  'aberdonian',
#  'bucephalus',
#  'heteropterous',
#  'image',
#  'cellulin',
#  'semiautomatic',
#  'blandly',
#  'myrrhol',
#  'dictyogenous',
#  'chicquer',
#  'androgynary',
#  'labrusca',
#  'maladministration',
#  'conscionably',
#  'playbill',
#  'rembrandt',
#  'bucerotes',
#  'bidet',
#  'objurgative',
#  'akcheh',
#  'coronal',
#  'instructed',
#  'plexure',
#  'angiostegnosis',
#  'aviatrix',
#  'lifesome',
#  'summonable',
#  'pericristate',
#  'flatways',
#  'megalopolitanism',
#  'rockshaft',
#  'setirostral',
#  'propublicity',
#  'occlusor',
#  'momentousness',
#  'criticize',
#  'detachable',
#  'nondiagonal',
#  'obstructant',
#  'sprayproof',
#  'tomalley',
#  'dirten',
#  'objectionist',
#  'sondylomorum',
#  'veta',
#  'clinology',
#  'tapeless',
#  'dysphonic',
#  'sleet',
#  'alarbus',
#  'autolysis',
#  'melanospermous',
#  'touristic',
#  'palamedeidae',
#  'pointman',
#  'zymolyis',
#  'crotonyl',
#  'nonsticky',
#  'scrupulous',
#  'unauthorizedly',
#  'trilogic',
#  'fopship',
#  'incompensation',
#  'forbearant',
#  'dogboat',
#  'disarchbishop',
#  'nidget',
#  'bombable',
#  'diaphragmatically',
#  'bugi',
#  'cartwrighting',
#  'whutter',
#  'hystricism',
#  'nebulization',
#  'napa',
#  'kaisership',
#  'pulsellum',
#  'aider',
#  'classicalize',
#  'conversive',
#  'aliturgical',
#  'haft',
#  'avidious',
#  'hydrostatic',
#  'semicircularly',
#  'valenciennes',
#  'bacterioprecipitin',
#  'zephyr',
#  'misregulate',
#  'bucorvinae',
#  'pinguid',
#  'klondiker',
#  'orthobiosis',
#  'royet',
#  'deliberalize',
#  'anticlogging',
#  'taxpaying',
#  'sucking',
#  'yeowoman',
#  'subpulverizer',
#  'jargon',
#  'unusably',
#  'hallucinator',
#  'inefficiently',
#  'iodide',
#  'mythically',
#  'snoreless',
#  'salomonic',
#  'calculatory',
#  'rectilineally',
#  'rustly',
#  'preponderate',
#  'humankind',
#  'squashiness',
#  'duodenocholedochotomy',
#  'unelapsed',
#  'burled',
#  'celibatarian',
#  'ultrapersuasive',
#  'gossipry',
#  'evenhanded',
#  'unkin',
#  'subungulata',
#  'unterribly',
#  'plectrum',
#  'sever',
#  'chorioidal',
#  'amphipeptone',
#  'gangsterism',
#  'myriotheism',
#  'toadeater',
#  'agrauleum',
#  'unmedaled',
#  'rhamphosuchus',
#  'cylindricule',
#  'encrinital',
#  'guidage',
#  'spiceful',
#  'galleried',
#  'clockhouse',
#  'douc',
#  'scribble',
#  'superassociate',
#  'various',
#  'postpituitary',
#  'mark',
#  'unraftered',
#  'butcheress',
#  'curledly',
#  'erythrocytorrhexis',
#  'asaphus',
#  'torpedoproof',
#  'humpless',
#  'orunchun',
#  'unpatentable',
#  'wonderberry',
#  'resinolic',
#  'bacillaceae',
#  'unhemmed',
#  'shadowgraph',
#  'mimpei',
#  'capercut',
#  'hernioid',
#  'unrivaled',
#  'dogberry',
#  'chiriana',
#  'metaconid',
#  'doketic',
#  'asperite',
#  'womanism',
#  'gastrocolpotomy',
#  'epileptoid',
#  'stuss',
#  'downcoming',
#  'arpen',
#  'catocalid',
#  'paction',
#  'casuist',
#  'forewish',
#  'marmarization',
#  'oscillatoria',
#  'tatianist',
#  'guessable',
#  'autoanalytic',
#  'ambuscade',
#  'micrologue',
#  'diander',
#  'hydroxide',
#  'sudorous',
#  'redesertion',
#  'motorization',
#  'basicity',
#  'clever',
#  'unoscillating',
#  'unsunburned',
#  'amatorious',
#  'plumatellidae',
#  'cyclotomic',
#  'duodenal',
#  'repressible',
#  'bunch',
#  'japaconine',
#  'overfluent',
#  'burao',
#  'leitneriaceae',
#  'diphenylchloroarsine',
#  'polymorphonucleate',
#  'primogenitor',
#  'tarbush',
#  'understocking',
#  'ranella',
#  'monothelitic',
#  'believing',
#  'perkin',
#  'almanac',
#  'louvering',
#  'havelock',
#  'heelstrap',
#  'eocene',
#  'spirous',
#  'expressionlessness',
#  'saturation',
#  'cephalochordata',
#  'oenothera',
#  'attentiveness',
#  'cymaphytism',
#  'chemicalization',
#  'cryptanalysis',
#  'unauthorized',
#  'uranoschism',
#  'colletes',
#  'fogou',
#  'dorsicommissure',
#  'kincob',
#  'angraecum',
#  'turbo',
#  'acridophagus',
#  'tesseradecade',
#  'ribbonry',
#  'paleology',
#  'processive',
#  'warship',
#  'hereticator',
#  'penthiophene',
#  'routing',
#  'denticular',
#  'unreviewed',
#  'awave',
#  'albertina',
#  'osteocachetic',
#  'polyciliate',
#  'cynomys',
#  'preparatively',
#  'dada',
#  'isogeothermal',
#  'outplease',
#  'dissentingly',
#  'tritoness',
#  'wondrously',
#  'hypercivilized',
#  'beguilement',
#  'endopsychic',
#  'dodecastyle',
#  'researchful',
#  'mime',
#  'rekindle',
#  'villageful',
#  'nonassignable',
#  'aerobatics',
#  'misopolemical',
#  'tabernariae',
#  'megalocephalic',
#  'adnexitis',
#  'hildegarde',
#  'maniacally',
#  'passingness',
#  'promisingly',
#  'musophaga',
#  'ophichthyoid',
#  'conceptiveness',
#  'lakshmi',
#  'congenially',
#  'trussing',
#  'ommateum',
#  'achlamydeous',
#  'tetarcone',
#  'taylor',
#  'morphographer',
#  'wilsome',
#  'wrigglingly',
#  'michelle',
#  'boxwallah',
#  'irrationalism',
#  'paraplasm',
#  'polybranch',
#  'metaplumbic',
#  'furfuraceously',
#  'coinclude',
#  'canonlike',
#  'thermo',
#  'beflannel',
#  'unfilled',
#  'preinsinuation',
#  'deflected',
#  'calpacked',
#  'ungreatness',
#  'mouthily',
#  'gantline',
#  'getling',
#  'tricyclene',
#  'unsecureness',
#  'pipewort',
#  'unsee',
#  'bardolatry',
#  'desynapsis',
#  'repugn',
#  'ballastage',
#  'boastful',
#  'orthospermous',
#  'garboil',
#  'preserveress',
#  'regressively',
#  'unbolled',
#  'miscreancy',
#  'roamer',
#  'unconvenience',
#  'tricot',
#  'aminoanthraquinone',
#  'phosphosilicate',
#  'electroballistic',
#  'microspherulitic',
#  'tilbury',
#  'nonsludging',
#  'mammaliferous',
#  'papilliform',
#  'podocarpus',
#  'virtualist',
#  'retinospora',
#  'diphthongize',
#  'nonclose',
#  'swinger',
#  'thomas',
#  'naumannite',
#  'ammocoetidae',
#  'umbellula',
#  'windbaggery',
#  'cardiorrhexis',
#  'uncompassionateness',
#  'supersuperior',
#  'unsteady',
#  'anthocerotales',
#  'edit',
#  'penetral',
#  'pulu',
#  'willowworm',
#  'chromobacterium',
#  'comparer',
#  'boneset',
#  'mothlike',
#  'sympathist',
#  'pisanite',
#  'desiderant',
#  'sporeling',
#  'dishcloth',
#  'dietotherapeutics',
#  'conchology',
#  'mesartim',
#  'yearful',
#  'rowdyishness',
#  'unfoxy',
#  'bout',
#  'sifflement',
#  'breadwinner',
#  'costard',
#  'heterokinetic',
#  'keraunoscopia',
#  'underbearing',
#  'cocainomaniac',
#  'isocrotonic',
#  'axseed',
#  'nae',
#  'unably',
#  'inditer',
#  'ogreishly',
#  'overdainty',
#  'logging',
#  'nipa',
#  'cuckooflower',
#  'ooidal',
#  'thwackstave',
#  'logicless',
#  'securigera',
#  'biangular',
#  'asiatize',
#  'trunkfish',
#  'calista',
#  'foeship',
#  'harehound',
#  'stiff',
#  'hieder',
#  'spealbone',
#  'absorbable',
#  'tikker',
#  'radiculitis',
#  'castrator',
#  'pseudodoxy',
#  'pneumobranchia',
#  'stionic',
#  'extrasolar',
#  'tetranychus',
#  'upblow',
#  'clavicular',
#  'riverwash',
#  'deportee',
#  'delphacid',
#  'averagely',
#  'dodecapetalous',
#  'formicide',
#  'floatage',
#  'thermotelephone',
#  'cyprididae',
#  'foyaitic',
#  'maquette',
#  'virgularian',
#  'flutterment',
#  'kaj',
#  'latidentate',
#  'unlooped',
#  'pecuniarily',
#  'overconfidently',
#  'nabobess',
#  'wifelet',
#  'scouthood',
#  'severalfold',
#  'antereformational',
#  'fullam',
#  'gonoblast',
#  'granulocyte',
#  'mediumistic',
#  'operatively',
#  'parentless',
#  'naphthamine',
#  'peridermic',
#  'nondirectional',
#  'tremandra',
#  'wattmeter',
#  'calciphilous',
#  'unindustrial',
#  'stupendously',
#  'pignorative',
#  'confidentialness',
#  'supracoralline',
#  'albuminize',
#  'creedmore',
#  'disaccustomedness',
#  'fibroangioma',
#  'lecanoraceous',
#  'duplicitas',
#  'zonure',
#  'chullpa',
#  'branchiostegidae',
#  'subkingdom',
#  'impassionedness',
#  'scandalproof',
#  'unfrenchified',
#  'retaliative',
#  'prudishness',
#  'antiecclesiastical',
#  'scorodite',
#  'tala',
#  'hyperdicrotic',
#  'follicular',
#  'brotherly',
#  'cydippida',
#  'pilate',
#  'synacmy',
#  'treeful',
#  'friarbird',
#  'grinnellia',
#  'splayfoot',
#  'yestreen',
#  'overbearingly',
#  'polyarchical',
#  'irrecollection',
#  'strontia',
#  'columban',
#  'expendability',
#  'pneumaturia',
#  'heartening',
#  'smallmouthed',
#  'songcraft',
#  'iridescently',
#  'pyrrhic',
#  'collaterally',
#  'reproclaim',
#  'tacksman',
#  'undisproving',
#  'coloquintid',
#  'micrographic',
#  'pisauridae',
#  'stilet',
#  'dystaxia',
#  'kukulcan',
#  'gyroidal',
#  'dolioform',
#  'ere',
#  'leatherside',
#  'clinometry',
#  'strati',
#  'ectocuneiform',
#  'dar',
#  'manyema',
#  'vitellus',
#  'expansional',
#  'hexahydrated',
#  'etherin',
#  'wentletrap',
#  'swelldom',
#  'passement',
#  'undangerous',
#  'womanfully',
#  'arupa',
#  'reconsecration',
#  'sedgelike',
#  'preoccipital',
#  'flitchen',
#  'tetraptote',
#  'semblance',
#  'methylosis',
#  'proctorrhagia',
#  'decomposed',
#  'conniption',
#  'unbarrenness',
#  'alternacy',
#  'endaortitis',
#  'kolkka',
#  'recapitalize',
#  'uncontestably',
#  'molar',
#  'empiricism',
#  'nitramine',
#  'desyl',
#  'wormian',
#  'unvoluntarily',
#  'ectal',
#  'unsanitation',
#  'gortonite',
#  'witherwards',
#  'sermonize',
#  'melanthaceous',
#  'trist',
#  'rattlepod',
#  'conventual',
#  'lissoflagellata',
#  'homoeomeri',
#  'copatroness',
#  'electromechanics',
#  'alkyloxy',
#  'interpage',
#  'unroiled',
#  'saving',
#  'axonophora',
#  'animalculism',
#  'marysole',
#  'heterometabola',
#  'viburnic',
#  'serious',
#  'nondialyzing',
#  'sultanin',
#  'platyfish',
#  'uncuriously',
#  'squamoepithelial',
#  'allocryptic',
#  'oxidase',
#  'leafcup',
#  'underflame',
#  'trindle',
#  'uncommenting',
#  'mummichog',
#  'wainscot',
#  'gloryful',
#  'crevasse',
#  'ducker',
#  'protostega',
#  'intermediator',
#  'uncompletely',
#  'unthrifty',
#  'prenoble',
#  'terrification',
#  'inburning',
#  'sursolid',
#  'wit',
#  ...}

# %%
# ...turned into a sorted list
words = sorted({line.strip().lower() for line in open('words.txt', 'r')})

# %%
words
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
#  'abashedness',
#  'abashless',
#  'abashlessly',
#  'abashment',
#  'abasia',
#  'abasic',
#  'abask',
#  'abassin',
#  'abastardize',
#  'abatable',
#  'abate',
#  'abatement',
#  'abater',
#  'abatis',
#  'abatised',
#  'abaton',
#  'abator',
#  'abattoir',
#  'abatua',
#  'abature',
#  'abave',
#  'abaxial',
#  'abaxile',
#  'abaze',
#  'abb',
#  'abba',
#  'abbacomes',
#  'abbacy',
#  'abbadide',
#  'abbas',
#  'abbasi',
#  'abbassi',
#  'abbasside',
#  'abbatial',
#  'abbatical',
#  'abbess',
#  'abbey',
#  'abbeystede',
#  'abbie',
#  'abbot',
#  'abbotcy',
#  'abbotnullius',
#  'abbotship',
#  'abbreviate',
#  'abbreviately',
#  'abbreviation',
#  'abbreviator',
#  'abbreviatory',
#  'abbreviature',
#  'abby',
#  'abcoulomb',
#  'abdal',
#  'abdat',
#  'abderian',
#  'abderite',
#  'abdest',
#  'abdicable',
#  'abdicant',
#  'abdicate',
#  'abdication',
#  'abdicative',
#  'abdicator',
#  'abdiel',
#  'abditive',
#  'abditory',
#  'abdomen',
#  'abdominal',
#  'abdominales',
#  'abdominalian',
#  'abdominally',
#  'abdominoanterior',
#  'abdominocardiac',
#  'abdominocentesis',
#  'abdominocystic',
#  'abdominogenital',
#  'abdominohysterectomy',
#  'abdominohysterotomy',
#  'abdominoposterior',
#  'abdominoscope',
#  'abdominoscopy',
#  'abdominothoracic',
#  'abdominous',
#  'abdominovaginal',
#  'abdominovesical',
#  'abduce',
#  'abducens',
#  'abducent',
#  'abduct',
#  'abduction',
#  'abductor',
#  'abe',
#  'abeam',
#  'abear',
#  'abearance',
#  'abecedarian',
#  'abecedarium',
#  'abecedary',
#  'abed',
#  'abeigh',
#  'abel',
#  'abele',
#  'abelia',
#  'abelian',
#  'abelicea',
#  'abelite',
#  'abelmoschus',
#  'abelmosk',
#  'abelonian',
#  'abeltree',
#  'abencerrages',
#  'abenteric',
#  'abepithymia',
#  'aberdeen',
#  'aberdevine',
#  'aberdonian',
#  'aberia',
#  'aberrance',
#  'aberrancy',
#  'aberrant',
#  'aberrate',
#  'aberration',
#  'aberrational',
#  'aberrator',
#  'aberrometer',
#  'aberroscope',
#  'aberuncator',
#  'abet',
#  'abetment',
#  'abettal',
#  'abettor',
#  'abevacuation',
#  'abey',
#  'abeyance',
#  'abeyancy',
#  'abeyant',
#  'abfarad',
#  'abhenry',
#  'abhiseka',
#  'abhominable',
#  'abhor',
#  'abhorrence',
#  'abhorrency',
#  'abhorrent',
#  'abhorrently',
#  'abhorrer',
#  'abhorrible',
#  'abhorring',
#  'abhorson',
#  'abidal',
#  'abidance',
#  'abide',
#  'abider',
#  'abidi',
#  'abiding',
#  'abidingly',
#  'abidingness',
#  'abie',
#  'abies',
#  'abietate',
#  'abietene',
#  'abietic',
#  'abietin',
#  'abietineae',
#  'abietineous',
#  'abietinic',
#  'abiezer',
#  'abigail',
#  'abigailship',
#  'abigeat',
#  'abigeus',
#  'abilao',
#  'ability',
#  'abilla',
#  'abilo',
#  'abintestate',
#  'abiogenesis',
#  'abiogenesist',
#  'abiogenetic',
#  'abiogenetical',
#  'abiogenetically',
#  'abiogenist',
#  'abiogenous',
#  'abiogeny',
#  'abiological',
#  'abiologically',
#  'abiology',
#  'abiosis',
#  'abiotic',
#  'abiotrophic',
#  'abiotrophy',
#  'abipon',
#  'abir',
#  'abirritant',
#  'abirritate',
#  'abirritation',
#  'abirritative',
#  'abiston',
#  'abitibi',
#  'abiuret',
#  'abject',
#  'abjectedness',
#  'abjection',
#  'abjective',
#  'abjectly',
#  'abjectness',
#  'abjoint',
#  'abjudge',
#  'abjudicate',
#  'abjudication',
#  'abjunction',
#  'abjunctive',
#  'abjuration',
#  'abjuratory',
#  'abjure',
#  'abjurement',
#  'abjurer',
#  'abkar',
#  'abkari',
#  'abkhas',
#  'abkhasian',
#  'ablach',
#  'ablactate',
#  'ablactation',
#  'ablare',
#  'ablastemic',
#  'ablastous',
#  'ablate',
#  'ablation',
#  'ablatitious',
#  'ablatival',
#  'ablative',
#  'ablator',
#  'ablaut',
#  'ablaze',
#  'able',
#  'ableeze',
#  'ablegate',
#  'ableness',
#  'ablepharia',
#  'ablepharon',
#  'ablepharous',
#  'ablepharus',
#  'ablepsia',
#  'ableptical',
#  'ableptically',
#  'abler',
#  'ablest',
#  'ablewhackets',
#  'ablins',
#  'abloom',
#  'ablow',
#  'ablude',
#  'abluent',
#  'ablush',
#  'ablution',
#  'ablutionary',
#  'abluvion',
#  'ably',
#  'abmho',
#  'abnaki',
#  'abnegate',
#  'abnegation',
#  'abnegative',
#  'abnegator',
#  'abner',
#  'abnerval',
#  'abnet',
#  'abneural',
#  'abnormal',
#  'abnormalism',
#  'abnormalist',
#  'abnormality',
#  'abnormalize',
#  'abnormally',
#  'abnormalness',
#  'abnormity',
#  'abnormous',
#  'abnumerable',
#  'abo',
#  'aboard',
#  'abobra',
#  'abode',
#  'abodement',
#  'abody',
#  'abohm',
#  'aboil',
#  'abolish',
#  'abolisher',
#  'abolishment',
#  'abolition',
#  'abolitionary',
#  'abolitionism',
#  'abolitionist',
#  'abolitionize',
#  'abolla',
#  'aboma',
#  'abomasum',
#  'abomasus',
#  'abominable',
#  'abominableness',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abominator',
#  'abomine',
#  'abongo',
#  'aboon',
#  'aborad',
#  'aboral',
#  'aborally',
#  'abord',
#  'aboriginal',
#  'aboriginality',
#  'aboriginally',
#  'aboriginary',
#  'aborigine',
#  'abort',
#  'aborted',
#  'aborticide',
#  'abortient',
#  'abortifacient',
#  'abortin',
#  'abortion',
#  'abortional',
#  'abortionist',
#  'abortive',
#  'abortively',
#  'abortiveness',
#  'abortus',
#  'abouchement',
#  'abound',
#  'abounder',
#  'abounding',
#  'aboundingly',
#  'about',
#  'abouts',
#  'above',
#  'aboveboard',
#  'abovedeck',
#  'aboveground',
#  'aboveproof',
#  'abovestairs',
#  'abox',
#  'abracadabra',
#  'abrachia',
#  'abradant',
#  'abrade',
#  'abrader',
#  'abraham',
#  'abrahamic',
#  'abrahamidae',
#  'abrahamite',
#  'abrahamitic',
#  'abraid',
#  'abram',
#  'abramis',
#  'abranchial',
#  'abranchialism',
#  'abranchian',
#  'abranchiata',
#  'abranchiate',
#  'abranchious',
#  'abrasax',
#  'abrase',
#  'abrash',
#  'abrasiometer',
#  'abrasion',
#  'abrasive',
#  'abrastol',
#  'abraum',
#  'abraxas',
#  'abreact',
#  'abreaction',
#  'abreast',
#  'abrenounce',
#  'abret',
#  'abrico',
#  'abridge',
#  'abridgeable',
#  'abridged',
#  'abridgedly',
#  'abridger',
#  'abridgment',
#  'abrim',
#  'abrin',
#  'abristle',
#  'abroach',
#  'abroad',
#  'abrocoma',
#  'abrocome',
#  'abrogable',
#  'abrogate',
#  'abrogation',
#  'abrogative',
#  'abrogator',
#  'abroma',
#  'abronia',
#  'abrook',
#  'abrotanum',
#  'abrotine',
#  'abrupt',
#  'abruptedly',
#  'abruption',
#  'abruptly',
#  'abruptness',
#  'abrus',
#  'absalom',
#  'absampere',
#  'absaroka',
#  'absarokite',
#  'abscess',
#  'abscessed',
#  'abscession',
#  'abscessroot',
#  'abscind',
#  'abscise',
#  'abscision',
#  'absciss',
#  'abscissa',
#  'abscissae',
#  'abscisse',
#  'abscission',
#  'absconce',
#  'abscond',
#  'absconded',
#  'abscondedly',
#  'abscondence',
#  'absconder',
#  'absconsa',
#  'abscoulomb',
#  'absence',
#  'absent',
#  'absentation',
#  'absentee',
#  'absenteeism',
#  'absenteeship',
#  'absenter',
#  'absently',
#  'absentment',
#  'absentmindedly',
#  'absentness',
#  'absfarad',
#  'abshenry',
#  'absi',
#  'absinthe',
#  'absinthial',
#  'absinthian',
#  'absinthiate',
#  'absinthic',
#  'absinthin',
#  'absinthine',
#  'absinthism',
#  'absinthismic',
#  'absinthium',
#  'absinthol',
#  'absit',
#  'absmho',
#  'absohm',
#  'absolute',
#  'absolutely',
#  'absoluteness',
#  'absolution',
#  'absolutism',
#  'absolutist',
#  'absolutistic',
#  'absolutistically',
#  'absolutive',
#  'absolutization',
#  'absolutize',
#  'absolutory',
#  'absolvable',
#  'absolvatory',
#  'absolve',
#  'absolvent',
#  'absolver',
#  'absolvitor',
#  'absolvitory',
#  'absonant',
#  'absonous',
#  'absorb',
#  'absorbability',
#  'absorbable',
#  'absorbed',
#  'absorbedly',
#  'absorbedness',
#  'absorbefacient',
#  'absorbency',
#  'absorbent',
#  'absorber',
#  'absorbing',
#  'absorbingly',
#  'absorbition',
#  'absorpt',
#  'absorptance',
#  'absorptiometer',
#  'absorptiometric',
#  'absorption',
#  'absorptive',
#  'absorptively',
#  'absorptiveness',
#  'absorptivity',
#  'absquatulate',
#  'abstain',
#  'abstainer',
#  'abstainment',
#  'abstemious',
#  'abstemiously',
#  'abstemiousness',
#  'abstention',
#  'abstentionist',
#  'abstentious',
#  'absterge',
#  'abstergent',
#  'abstersion',
#  'abstersive',
#  'abstersiveness',
#  'abstinence',
#  'abstinency',
#  'abstinent',
#  'abstinential',
#  'abstinently',
#  'abstract',
#  'abstracted',
#  'abstractedly',
#  'abstractedness',
#  'abstracter',
#  'abstraction',
#  'abstractional',
#  'abstractionism',
#  'abstractionist',
#  'abstractitious',
#  'abstractive',
#  'abstractively',
#  'abstractiveness',
#  'abstractly',
#  'abstractness',
#  'abstractor',
#  'abstrahent',
#  'abstricted',
#  'abstriction',
#  'abstruse',
#  'abstrusely',
#  'abstruseness',
#  'abstrusion',
#  'abstrusity',
#  'absume',
#  'absumption',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'absvolt',
#  'absyrtus',
#  'abterminal',
#  'abthain',
#  'abthainrie',
#  'abthainry',
#  'abthanage',
#  'abu',
#  'abucco',
#  'abulia',
#  'abulic',
#  'abulomania',
#  'abuna',
#  'abundance',
#  'abundancy',
#  'abundant',
#  'abundantia',
#  'abundantly',
#  'abura',
#  'aburabozu',
#  'aburban',
#  'aburst',
#  'aburton',
#  'abusable',
#  'abuse',
#  'abusedly',
#  'abusee',
#  'abuseful',
#  'abusefully',
#  'abusefulness',
#  'abuser',
#  'abusion',
#  'abusious',
#  'abusive',
#  'abusively',
#  'abusiveness',
#  'abut',
#  'abuta',
#  'abutilon',
#  'abutment',
#  'abuttal',
#  'abutter',
#  'abutting',
#  'abuzz',
#  'abvolt',
#  'abwab',
#  'aby',
#  'abysm',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'abyssal',
#  'abyssinian',
#  'abyssobenthonic',
#  'abyssolith',
#  'abyssopelagic',
#  'acacatechin',
#  'acacatechol',
#  'acacetin',
#  'acacia',
#  'acacian',
#  'acaciin',
#  'acacin',
#  'academe',
#  'academial',
#  'academian',
#  'academic',
#  'academical',
#  'academically',
#  'academicals',
#  'academician',
#  'academicism',
#  'academism',
#  'academist',
#  'academite',
#  'academization',
#  'academize',
#  'academus',
#  'academy',
#  'acadia',
#  'acadialite',
#  'acadian',
#  'acadie',
#  'acaena',
#  'acajou',
#  'acaleph',
#  'acalepha',
#  'acalephae',
#  'acalephan',
#  'acalephoid',
#  'acalycal',
#  'acalycine',
#  'acalycinous',
#  'acalyculate',
#  'acalypha',
#  'acalypterae',
#  'acalyptrata',
#  'acalyptratae',
#  'acalyptrate',
#  'acamar',
#  'acampsia',
#  'acana',
#  'acanaceous',
#  'acanonical',
#  'acanth',
#  'acantha',
#  'acanthaceae',
#  'acanthaceous',
#  'acanthad',
#  'acantharia',
#  'acanthia',
#  'acanthial',
#  'acanthin',
#  'acanthine',
#  'acanthion',
#  'acanthite',
#  'acanthocarpous',
#  'acanthocephala',
#  'acanthocephalan',
#  'acanthocephali',
#  'acanthocephalous',
#  'acanthocereus',
#  'acanthocladous',
#  'acanthodea',
#  'acanthodean',
#  'acanthodei',
#  'acanthodes',
#  'acanthodian',
#  'acanthodidae',
#  'acanthodii',
#  'acanthodini',
#  'acanthoid',
#  'acantholimon',
#  'acanthological',
#  'acanthology',
#  'acantholysis',
#  'acanthoma',
#  'acanthomeridae',
#  'acanthon',
#  'acanthopanax',
#  'acanthophis',
#  'acanthophorous',
#  'acanthopod',
#  'acanthopodous',
#  'acanthopomatous',
#  'acanthopore',
#  'acanthopteran',
#  'acanthopteri',
#  'acanthopterous',
#  'acanthopterygian',
#  'acanthopterygii',
#  'acanthosis',
#  'acanthous',
#  'acanthuridae',
#  'acanthurus',
#  'acanthus',
#  'acapnia',
#  'acapnial',
#  'acapsular',
#  'acapu',
#  'acapulco',
#  'acara',
#  'acarapis',
#  'acardia',
#  'acardiac',
#  'acari',
#  'acarian',
#  'acariasis',
#  'acaricidal',
#  'acaricide',
#  'acarid',
#  'acarida',
#  'acaridea',
#  'acaridean',
#  'acaridomatium',
#  'acariform',
#  'acarina',
#  'acarine',
#  'acarinosis',
#  'acarocecidium',
#  'acarodermatitis',
#  'acaroid',
#  'acarol',
#  'acarologist',
#  'acarology',
#  'acarophilous',
#  'acarophobia',
#  'acarotoxic',
#  'acarpelous',
#  'acarpous',
#  'acarus',
#  'acastus',
#  'acatalectic',
#  'acatalepsia',
#  'acatalepsy',
#  'acataleptic',
#  'acatallactic',
#  'acatamathesia',
#  'acataphasia',
#  'acataposis',
#  'acatastasia',
#  'acatastatic',
#  'acate',
#  'acategorical',
#  'acatery',
#  'acatharsia',
#  'acatharsy',
#  'acatholic',
#  'acaudal',
#  'acaudate',
#  'acaulescent',
#  'acauline',
#  'acaulose',
#  'acaulous',
#  'acca',
#  'accede',
#  'accedence',
#  'acceder',
#  'accelerable',
#  'accelerando',
#  'accelerant',
#  'accelerate',
#  'accelerated',
#  'acceleratedly',
#  'acceleration',
#  'accelerative',
#  'accelerator',
#  'acceleratory',
#  'accelerograph',
#  'accelerometer',
#  'accend',
#  'accendibility',
#  'accendible',
#  'accension',
#  'accensor',
#  'accent',
#  'accentless',
#  'accentor',
#  'accentuable',
#  'accentual',
#  'accentuality',
#  'accentually',
#  'accentuate',
#  'accentuation',
#  'accentuator',
#  'accentus',
#  'accept',
#  'acceptability',
#  'acceptable',
#  'acceptableness',
#  'acceptably',
#  'acceptance',
#  'acceptancy',
#  'acceptant',
#  'acceptation',
#  'accepted',
#  'acceptedly',
#  'accepter',
#  'acceptilate',
#  'acceptilation',
#  'acception',
#  'acceptive',
#  'acceptor',
#  'acceptress',
#  'accerse',
#  'accersition',
#  'accersitor',
#  'access',
#  'accessarily',
#  'accessariness',
#  'accessary',
#  'accessaryship',
#  'accessibility',
#  'accessible',
#  'accessibly',
#  'accession',
#  'accessional',
#  'accessioner',
#  'accessive',
#  'accessively',
#  'accessless',
#  'accessorial',
#  'accessorily',
#  'accessoriness',
#  'accessorius',
#  'accessory',
#  'accidence',
#  'accidency',
#  'accident',
#  'accidental',
#  'accidentalism',
#  'accidentalist',
#  'accidentality',
#  'accidentally',
#  'accidentalness',
#  'accidented',
#  'accidential',
#  'accidentiality',
#  'accidently',
#  'accidia',
#  'accidie',
#  'accinge',
#  'accipient',
#  'accipiter',
#  'accipitral',
#  'accipitrary',
#  'accipitres',
#  'accipitrine',
#  'accismus',
#  'accite',
#  'acclaim',
#  'acclaimable',
#  'acclaimer',
#  'acclamation',
#  'acclamator',
#  'acclamatory',
#  'acclimatable',
#  'acclimatation',
#  'acclimate',
#  'acclimatement',
#  'acclimation',
#  'acclimatizable',
#  'acclimatization',
#  'acclimatize',
#  'acclimatizer',
#  'acclimature',
#  'acclinal',
#  'acclinate',
#  'acclivitous',
#  'acclivity',
#  'acclivous',
#  'accloy',
#  'accoast',
#  'accoil',
#  'accolade',
#  'accoladed',
#  'accolated',
#  'accolent',
#  'accolle',
#  'accombination',
#  'accommodable',
#  'accommodableness',
#  'accommodate',
#  'accommodately',
#  'accommodateness',
#  'accommodating',
#  'accommodatingly',
#  'accommodation',
#  'accommodational',
#  'accommodative',
#  'accommodativeness',
#  'accommodator',
#  'accompanier',
#  'accompaniment',
#  'accompanimental',
#  'accompanist',
#  'accompany',
#  'accompanyist',
#  'accompletive',
#  'accomplice',
#  'accompliceship',
#  'accomplicity',
#  'accomplish',
#  'accomplishable',
#  'accomplished',
#  'accomplisher',
#  'accomplishment',
#  'accomplisht',
#  'accompt',
#  'accord',
#  'accordable',
#  'accordance',
#  'accordancy',
#  'accordant',
#  'accordantly',
#  'accorder',
#  'according',
#  'accordingly',
#  'accordion',
#  ...]

# %%
# return a list of all lines from an open file 
open('francais.txt', 'r', encoding='latin1').readlines()
# Out:
# ['\n',
#  'a\n',
#  'ab\n',
#  'abaissa\n',
#  'abaissai\n',
#  'abaissaient\n',
#  'abaissais\n',
#  'abaissait\n',
#  'abaissant\n',
#  'abaissas\n',
#  'abaissasse\n',
#  'abaissassent\n',
#  'abaissasses\n',
#  'abaissassiez\n',
#  'abaissassions\n',
#  'abaissâmes\n',
#  'abaissât\n',
#  'abaissâtes\n',
#  'abaisse\n',
#  'abaissement\n',
#  'abaissements\n',
#  'abaissent\n',
#  'abaisser\n',
#  'abaissera\n',
#  'abaisserai\n',
#  'abaisseraient\n',
#  'abaisserais\n',
#  'abaisserait\n',
#  'abaisseras\n',
#  'abaisserez\n',
#  'abaisseriez\n',
#  'abaisserions\n',
#  'abaisserons\n',
#  'abaisseront\n',
#  'abaisses\n',
#  'abaisseur\n',
#  'abaisseurs\n',
#  'abaissez\n',
#  'abaissé\n',
#  'abaissée\n',
#  'abaissées\n',
#  'abaissés\n',
#  'abaissèrent\n',
#  'abaissiez\n',
#  'abaissions\n',
#  'abaissons\n',
#  'abandon\n',
#  'abandonna\n',
#  'abandonnai\n',
#  'abandonnaient\n',
#  'abandonnais\n',
#  'abandonnait\n',
#  'abandonnant\n',
#  'abandonnas\n',
#  'abandonnasse\n',
#  'abandonnassent\n',
#  'abandonnasses\n',
#  'abandonnassiez\n',
#  'abandonnassions\n',
#  'abandonnâmes\n',
#  'abandonnât\n',
#  'abandonnâtes\n',
#  'abandonne\n',
#  'abandonnent\n',
#  'abandonner\n',
#  'abandonnera\n',
#  'abandonnerai\n',
#  'abandonneraient\n',
#  'abandonnerais\n',
#  'abandonnerait\n',
#  'abandonneras\n',
#  'abandonnerez\n',
#  'abandonneriez\n',
#  'abandonnerions\n',
#  'abandonnerons\n',
#  'abandonneront\n',
#  'abandonnes\n',
#  'abandonnez\n',
#  'abandonné\n',
#  'abandonnée\n',
#  'abandonnées\n',
#  'abandonnés\n',
#  'abandonnèrent\n',
#  'abandonniez\n',
#  'abandonnions\n',
#  'abandonnons\n',
#  'abandons\n',
#  'abaque\n',
#  'abaques\n',
#  'abasourdi\n',
#  'abasourdie\n',
#  'abasourdies\n',
#  'abasourdir\n',
#  'abasourdira\n',
#  'abasourdirai\n',
#  'abasourdiraient\n',
#  'abasourdirais\n',
#  'abasourdirait\n',
#  'abasourdiras\n',
#  'abasourdirent\n',
#  'abasourdirez\n',
#  'abasourdiriez\n',
#  'abasourdirions\n',
#  'abasourdirons\n',
#  'abasourdiront\n',
#  'abasourdis\n',
#  'abasourdissaient\n',
#  'abasourdissais\n',
#  'abasourdissait\n',
#  'abasourdissant\n',
#  'abasourdissante\n',
#  'abasourdissantes\n',
#  'abasourdissants\n',
#  'abasourdisse\n',
#  'abasourdissement\n',
#  'abasourdissements\n',
#  'abasourdissent\n',
#  'abasourdisses\n',
#  'abasourdissez\n',
#  'abasourdissiez\n',
#  'abasourdissions\n',
#  'abasourdissons\n',
#  'abasourdit\n',
#  'abasourdîmes\n',
#  'abasourdît\n',
#  'abasourdîtes\n',
#  'abat\n',
#  'abats\n',
#  'abattage\n',
#  'abattages\n',
#  'abattaient\n',
#  'abattais\n',
#  'abattait\n',
#  'abattant\n',
#  'abattants\n',
#  'abattement\n',
#  'abattements\n',
#  'abattez\n',
#  'abattiez\n',
#  'abattions\n',
#  'abattirent\n',
#  'abattis\n',
#  'abattisse\n',
#  'abattissent\n',
#  'abattisses\n',
#  'abattissiez\n',
#  'abattissions\n',
#  'abattit\n',
#  'abattîmes\n',
#  'abattît\n',
#  'abattîtes\n',
#  'abattoir\n',
#  'abattoirs\n',
#  'abattra\n',
#  'abattrai\n',
#  'abattraient\n',
#  'abattrais\n',
#  'abattrait\n',
#  'abattras\n',
#  'abattre\n',
#  'abattrez\n',
#  'abattriez\n',
#  'abattrions\n',
#  'abattrons\n',
#  'abattront\n',
#  'abattu\n',
#  'abattue\n',
#  'abattues\n',
#  'abattures\n',
#  'abattus\n',
#  'abâtardi\n',
#  'abâtardie\n',
#  'abâtardies\n',
#  'abâtardir\n',
#  'abâtardira\n',
#  'abâtardirai\n',
#  'abâtardiraient\n',
#  'abâtardirais\n',
#  'abâtardirait\n',
#  'abâtardiras\n',
#  'abâtardirent\n',
#  'abâtardirez\n',
#  'abâtardiriez\n',
#  'abâtardirions\n',
#  'abâtardirons\n',
#  'abâtardiront\n',
#  'abâtardis\n',
#  'abâtardisaient\n',
#  'abâtardisais\n',
#  'abâtardisait\n',
#  'abâtardisant\n',
#  'abâtardisse\n',
#  'abâtardissement\n',
#  'abâtardissements\n',
#  'abâtardissent\n',
#  'abâtardisses\n',
#  'abâtardissez\n',
#  'abâtardissiez\n',
#  'abâtardissions\n',
#  'abâtardissons\n',
#  'abâtardit\n',
#  'abâtardîmes\n',
#  'abâtardît\n',
#  'abâtardîtes\n',
#  'abbatial\n',
#  'abbatiale\n',
#  'abbatiales\n',
#  'abbatiaux\n',
#  'abbaye\n',
#  'abbayes\n',
#  'abbesse\n',
#  'abbesses\n',
#  'abbé\n',
#  'abbés\n',
#  'abcès\n',
#  'abdication\n',
#  'abdications\n',
#  'abdiqua\n',
#  'abdiquai\n',
#  'abdiquaient\n',
#  'abdiquais\n',
#  'abdiquait\n',
#  'abdiquant\n',
#  'abdiquas\n',
#  'abdiquasse\n',
#  'abdiquassent\n',
#  'abdiquasses\n',
#  'abdiquassiez\n',
#  'abdiquassions\n',
#  'abdiquâmes\n',
#  'abdiquât\n',
#  'abdiquâtes\n',
#  'abdique\n',
#  'abdiquent\n',
#  'abdiquer\n',
#  'abdiquera\n',
#  'abdiquerai\n',
#  'abdiqueraient\n',
#  'abdiquerais\n',
#  'abdiquerait\n',
#  'abdiqueras\n',
#  'abdiquerez\n',
#  'abdiqueriez\n',
#  'abdiquerions\n',
#  'abdiquerons\n',
#  'abdiqueront\n',
#  'abdiques\n',
#  'abdiquez\n',
#  'abdiqué\n',
#  'abdiquée\n',
#  'abdiquées\n',
#  'abdiqués\n',
#  'abdiquèrent\n',
#  'abdiquiez\n',
#  'abdiquions\n',
#  'abdiquons\n',
#  'abdomen\n',
#  'abdomens\n',
#  'abdominal\n',
#  'abdominale\n',
#  'abdominales\n',
#  'abdominaux\n',
#  'abducteur\n',
#  'abducteurs\n',
#  'abduction\n',
#  'abductions\n',
#  'abeille\n',
#  'abeilles\n',
#  'aberrant\n',
#  'aberrante\n',
#  'aberrantes\n',
#  'aberrants\n',
#  'aberration\n',
#  'aberrations\n',
#  'abêti\n',
#  'abêtie\n',
#  'abêties\n',
#  'abêtir\n',
#  'abêtira\n',
#  'abêtirai\n',
#  'abêtiraient\n',
#  'abêtirais\n',
#  'abêtirait\n',
#  'abêtiras\n',
#  'abêtirent\n',
#  'abêtirez\n',
#  'abêtiriez\n',
#  'abêtirions\n',
#  'abêtirons\n',
#  'abêtiront\n',
#  'abêtis\n',
#  'abêtissaient\n',
#  'abêtissais\n',
#  'abêtissait\n',
#  'abêtissant\n',
#  'abêtissante\n',
#  'abêtissantes\n',
#  'abêtissants\n',
#  'abêtissement\n',
#  'abêtissements\n',
#  'abêtissent\n',
#  'abêtisses\n',
#  'abêtissez\n',
#  'abêtissiez\n',
#  'abêtissions\n',
#  'abêtissons\n',
#  'abêtit\n',
#  'abêtîmes\n',
#  'abêtît\n',
#  'abêtîtes\n',
#  'abhorra\n',
#  'abhorrai\n',
#  'abhorraient\n',
#  'abhorrais\n',
#  'abhorrait\n',
#  'abhorrant\n',
#  'abhorras\n',
#  'abhorrasse\n',
#  'abhorrassent\n',
#  'abhorrasses\n',
#  'abhorrassiez\n',
#  'abhorrassions\n',
#  'abhorrâmes\n',
#  'abhorrât\n',
#  'abhorrâtes\n',
#  'abhorre\n',
#  'abhorrent\n',
#  'abhorrer\n',
#  'abhorrera\n',
#  'abhorrerai\n',
#  'abhorreraient\n',
#  'abhorrerais\n',
#  'abhorrerait\n',
#  'abhorreras\n',
#  'abhorrerez\n',
#  'abhorreriez\n',
#  'abhorrerions\n',
#  'abhorrerons\n',
#  'abhorreront\n',
#  'abhorres\n',
#  'abhorrez\n',
#  'abhorré\n',
#  'abhorrée\n',
#  'abhorrées\n',
#  'abhorrés\n',
#  'abhorrèrent\n',
#  'abhorriez\n',
#  'abhorrions\n',
#  'abhorrons\n',
#  'abîma\n',
#  'abîmai\n',
#  'abîmaient\n',
#  'abîmais\n',
#  'abîmait\n',
#  'abîmant\n',
#  'abîmas\n',
#  'abîmasse\n',
#  'abîmassent\n',
#  'abîmasses\n',
#  'abîmassiez\n',
#  'abîmassions\n',
#  'abîmâmes\n',
#  'abîmât\n',
#  'abîmâtes\n',
#  'abîme\n',
#  'abîment\n',
#  'abîmer\n',
#  'abîmera\n',
#  'abîmerai\n',
#  'abîmeraient\n',
#  'abîmerais\n',
#  'abîmerait\n',
#  'abîmeras\n',
#  'abîmerez\n',
#  'abîmeriez\n',
#  'abîmerions\n',
#  'abîmerons\n',
#  'abîmeront\n',
#  'abîmes\n',
#  'abîmez\n',
#  'abîmé\n',
#  'abîmée\n',
#  'abîmées\n',
#  'abîmés\n',
#  'abîmèrent\n',
#  'abîmiez\n',
#  'abîmions\n',
#  'abîmons\n',
#  'abject\n',
#  'abjecte\n',
#  'abjectes\n',
#  'abjection\n',
#  'abjections\n',
#  'abjects\n',
#  'abjura\n',
#  'abjurai\n',
#  'abjuraient\n',
#  'abjurais\n',
#  'abjurait\n',
#  'abjurant\n',
#  'abjuras\n',
#  'abjurasse\n',
#  'abjurassent\n',
#  'abjurasses\n',
#  'abjurassiez\n',
#  'abjurassions\n',
#  'abjuration\n',
#  'abjurations\n',
#  'abjurâmes\n',
#  'abjurât\n',
#  'abjurâtes\n',
#  'abjure\n',
#  'abjurent\n',
#  'abjurer\n',
#  'abjurera\n',
#  'abjurerai\n',
#  'abjureraient\n',
#  'abjurerais\n',
#  'abjurerait\n',
#  'abjureras\n',
#  'abjurerez\n',
#  'abjureriez\n',
#  'abjurerions\n',
#  'abjurerons\n',
#  'abjureront\n',
#  'abjures\n',
#  'abjurez\n',
#  'abjuré\n',
#  'abjurée\n',
#  'abjurées\n',
#  'abjurés\n',
#  'abjurèrent\n',
#  'abjuriez\n',
#  'abjurions\n',
#  'abjurons\n',
#  'ablatif\n',
#  'ablation\n',
#  'ablations\n',
#  'ablette\n',
#  'ablettes\n',
#  'ablution\n',
#  'ablutions\n',
#  'abnégation\n',
#  'abnégations\n',
#  'aboi\n',
#  'aboie\n',
#  'aboiement\n',
#  'aboiements\n',
#  'aboient\n',
#  'aboiera\n',
#  'aboierai\n',
#  'aboieraient\n',
#  'aboieraiez\n',
#  'aboieraions\n',
#  'aboierais\n',
#  'aboierait\n',
#  'aboieras\n',
#  'aboierez\n',
#  'aboierons\n',
#  'aboieront\n',
#  'aboies\n',
#  'abois\n',
#  'aboli\n',
#  'abolie\n',
#  'abolies\n',
#  'abolir\n',
#  'abolira\n',
#  'abolirai\n',
#  'aboliraient\n',
#  'abolirais\n',
#  'abolirait\n',
#  'aboliras\n',
#  'abolirent\n',
#  'abolirez\n',
#  'aboliriez\n',
#  'abolirions\n',
#  'abolirons\n',
#  'aboliront\n',
#  'abolis\n',
#  'abolissaient\n',
#  'abolissais\n',
#  'abolissait\n',
#  'abolissant\n',
#  'abolisse\n',
#  'abolissent\n',
#  'abolisses\n',
#  'abolissez\n',
#  'abolissiez\n',
#  'abolissions\n',
#  'abolissons\n',
#  'abolit\n',
#  'abolition\n',
#  'abolitionnisme\n',
#  'abolitionniste\n',
#  'abolitionnistes\n',
#  'abolitions\n',
#  'abolîmes\n',
#  'abolît\n',
#  'abolîtes\n',
#  'abomina\n',
#  'abominable\n',
#  'abominablement\n',
#  'abominables\n',
#  'abominai\n',
#  'abominaient\n',
#  'abominais\n',
#  'abominait\n',
#  'abominant\n',
#  'abominas\n',
#  'abominasse\n',
#  'abominassent\n',
#  'abominasses\n',
#  'abominassiez\n',
#  'abominassions\n',
#  'abomination\n',
#  'abominations\n',
#  'abominâmes\n',
#  'abominât\n',
#  'abominâtes\n',
#  'abomine\n',
#  'abominent\n',
#  'abominer\n',
#  'abominera\n',
#  'abominerai\n',
#  'abomineraient\n',
#  'abominerais\n',
#  'abominerait\n',
#  'abomineras\n',
#  'abominerez\n',
#  'abomineriez\n',
#  'abominerions\n',
#  'abominerons\n',
#  'abomineront\n',
#  'abomines\n',
#  'abominez\n',
#  'abominé\n',
#  'abominée\n',
#  'abominées\n',
#  'abominés\n',
#  'abominèrent\n',
#  'abominiez\n',
#  'abominions\n',
#  'abominons\n',
#  'abonda\n',
#  'abondai\n',
#  'abondaient\n',
#  'abondais\n',
#  'abondait\n',
#  'abondamment\n',
#  'abondance\n',
#  'abondances\n',
#  'abondant\n',
#  'abondante\n',
#  'abondantes\n',
#  'abondants\n',
#  'abondas\n',
#  'abondasse\n',
#  'abondassent\n',
#  'abondasses\n',
#  'abondassiez\n',
#  'abondassions\n',
#  'abondâmes\n',
#  'abondât\n',
#  'abondâtes\n',
#  'abonde\n',
#  'abondent\n',
#  'abonder\n',
#  'abondera\n',
#  'abonderai\n',
#  'abonderaient\n',
#  'abonderais\n',
#  'abonderait\n',
#  'abonderas\n',
#  'abonderez\n',
#  'abonderiez\n',
#  'abonderions\n',
#  'abonderons\n',
#  'abonderont\n',
#  'abondes\n',
#  'abondez\n',
#  'abondé\n',
#  'abondée\n',
#  'abondées\n',
#  'abondés\n',
#  'abondèrent\n',
#  'abondiez\n',
#  'abondions\n',
#  'abondons\n',
#  'abonna\n',
#  'abonnai\n',
#  'abonnaient\n',
#  'abonnais\n',
#  'abonnait\n',
#  'abonnant\n',
#  'abonnas\n',
#  'abonnasse\n',
#  'abonnassent\n',
#  'abonnasses\n',
#  'abonnassiez\n',
#  'abonnassions\n',
#  'abonnâmes\n',
#  'abonnât\n',
#  'abonnâtes\n',
#  'abonne\n',
#  'abonnement\n',
#  'abonnements\n',
#  'abonnent\n',
#  'abonner\n',
#  'abonnera\n',
#  'abonnerai\n',
#  'abonneraient\n',
#  'abonnerais\n',
#  'abonnerait\n',
#  'abonneras\n',
#  'abonnerez\n',
#  'abonneriez\n',
#  'abonnerions\n',
#  'abonnerons\n',
#  'abonneront\n',
#  'abonnes\n',
#  'abonnez\n',
#  'abonné\n',
#  'abonnée\n',
#  'abonnées\n',
#  'abonnés\n',
#  'abonnèrent\n',
#  'abonni\n',
#  'abonnie\n',
#  'abonnies\n',
#  'abonniez\n',
#  'abonnions\n',
#  'abonnir\n',
#  'abonnira\n',
#  'abonnirai\n',
#  'abonniraient\n',
#  'abonnirais\n',
#  'abonnirait\n',
#  'abonniras\n',
#  'abonnirent\n',
#  'abonnirez\n',
#  'abonniriez\n',
#  'abonnirions\n',
#  'abonnirons\n',
#  'abonniront\n',
#  'abonnis\n',
#  'abonnissaient\n',
#  'abonnissais\n',
#  'abonnissait\n',
#  'abonnissant\n',
#  'abonnisse\n',
#  'abonnissent\n',
#  'abonnisses\n',
#  'abonnissez\n',
#  'abonnissiez\n',
#  'abonnissions\n',
#  'abonnissons\n',
#  'abonnit\n',
#  'abonnîmes\n',
#  'abonnît\n',
#  'abonnîtes\n',
#  'abonnon\n',
#  'abonnons\n',
#  'abord\n',
#  'aborda\n',
#  'abordable\n',
#  'abordables\n',
#  'abordage\n',
#  'abordages\n',
#  'abordai\n',
#  'abordaient\n',
#  'abordais\n',
#  'abordait\n',
#  'abordant\n',
#  'abordas\n',
#  'abordasse\n',
#  'abordassent\n',
#  'abordasses\n',
#  'abordassiez\n',
#  'abordassions\n',
#  'abordâmes\n',
#  'abordât\n',
#  'abordâtes\n',
#  'aborde\n',
#  'abordent\n',
#  'aborder\n',
#  'abordera\n',
#  'aborderai\n',
#  'aborderaient\n',
#  'aborderais\n',
#  'aborderait\n',
#  'aborderas\n',
#  'aborderez\n',
#  'aborderiez\n',
#  'aborderions\n',
#  'aborderons\n',
#  'aborderont\n',
#  'abordes\n',
#  'abordez\n',
#  'abordé\n',
#  'abordée\n',
#  'abordées\n',
#  'abordés\n',
#  'abordèrent\n',
#  'abordiez\n',
#  'abordions\n',
#  'abordons\n',
#  'abords\n',
#  'aborigène\n',
#  'aborigènes\n',
#  'abortif\n',
#  'abortifs\n',
#  'abortive\n',
#  'abortives\n',
#  'aboucha\n',
#  'abouchai\n',
#  'abouchaient\n',
#  'abouchais\n',
#  'abouchait\n',
#  'abouchant\n',
#  'abouchas\n',
#  'abouchasse\n',
#  'abouchassent\n',
#  'abouchasses\n',
#  'abouchassiez\n',
#  'abouchassions\n',
#  'abouchâmes\n',
#  'abouchât\n',
#  'abouchâtes\n',
#  'abouche\n',
#  'abouchent\n',
#  'aboucher\n',
#  'abouchera\n',
#  'aboucherai\n',
#  'aboucheraient\n',
#  'aboucherais\n',
#  'aboucherait\n',
#  'aboucheras\n',
#  'aboucherez\n',
#  'aboucheriez\n',
#  'aboucherions\n',
#  'aboucherons\n',
#  'aboucheront\n',
#  'abouches\n',
#  'abouchez\n',
#  'abouché\n',
#  'abouchée\n',
#  'abouchées\n',
#  'abouchés\n',
#  'abouchèrent\n',
#  'abouchiez\n',
#  'abouchions\n',
#  'abouchons\n',
#  'aboulie\n',
#  'aboulies\n',
#  'aboulique\n',
#  'abouliques\n',
#  'abouti\n',
#  'aboutie\n',
#  'abouties\n',
#  'aboutir\n',
#  'aboutira\n',
#  'aboutiraient\n',
#  'aboutirais\n',
#  'aboutirait\n',
#  'aboutiras\n',
#  'aboutirent\n',
#  'aboutirez\n',
#  'aboutiriez\n',
#  'aboutirions\n',
#  'aboutirons\n',
#  'aboutiront\n',
#  'aboutis\n',
#  'aboutissaient\n',
#  'aboutissais\n',
#  'aboutissait\n',
#  'aboutissant\n',
#  'aboutissants\n',
#  'aboutisse\n',
#  'aboutissement\n',
#  'aboutissements\n',
#  'aboutissent\n',
#  'aboutisses\n',
#  'aboutissez\n',
#  'aboutissiez\n',
#  'aboutissions\n',
#  'aboutissons\n',
#  'aboutit\n',
#  'aboutîmes\n',
#  'aboutît\n',
#  'aboutîtes\n',
#  'aboya\n',
#  'aboyai\n',
#  'aboyaient\n',
#  'aboyais\n',
#  'aboyait\n',
#  'aboyant\n',
#  'aboyasse\n',
#  'aboyassent\n',
#  'aboyasses\n',
#  'aboyassiez\n',
#  'aboyassions\n',
#  'aboyâmes\n',
#  'aboyât\n',
#  'aboyâtes\n',
#  'aboyer\n',
#  'aboyeur\n',
#  'aboyeurs\n',
#  'aboyeuse\n',
#  'aboyeuses\n',
#  'aboyez\n',
#  'aboyé\n',
#  'aboyée\n',
#  'aboyées\n',
#  'aboyés\n',
#  'aboyèrent\n',
#  'aboyiez\n',
#  'aboyions\n',
#  'aboyons\n',
#  'abracadabrant\n',
#  'abracadabrante\n',
#  'abracadabrantes\n',
#  'abracadabrants\n',
#  'abrasif\n',
#  'abrasifs\n',
#  'abrasion\n',
#  'abrasions\n',
#  'abrasive\n',
#  'abrasives\n',
#  'abreuva\n',
#  'abreuvai\n',
#  'abreuvaient\n',
#  'abreuvais\n',
#  'abreuvait\n',
#  'abreuvant\n',
#  'abreuvas\n',
#  'abreuvasse\n',
#  'abreuvassent\n',
#  'abreuvasses\n',
#  'abreuvassiez\n',
#  'abreuvassions\n',
#  'abreuvâmes\n',
#  'abreuvât\n',
#  'abreuvâtes\n',
#  'abreuve\n',
#  'abreuvent\n',
#  'abreuver\n',
#  'abreuvera\n',
#  'abreuverai\n',
#  'abreuveraient\n',
#  'abreuverais\n',
#  'abreuverait\n',
#  'abreuveras\n',
#  'abreuverez\n',
#  'abreuveriez\n',
#  'abreuverions\n',
#  'abreuverons\n',
#  'abreuveront\n',
#  'abreuves\n',
#  'abreuvez\n',
#  'abreuvé\n',
#  'abreuvée\n',
#  'abreuvées\n',
#  'abreuvés\n',
#  'abreuvèrent\n',
#  'abreuviez\n',
#  'abreuvions\n',
#  'abreuvoir\n',
#  'abreuvoirs\n',
#  'abreuvons\n',
#  'abrége\n',
#  'abrégea\n',
#  'abrégeai\n',
#  'abrégeaient\n',
#  'abrégeais\n',
#  'abrégeait\n',
#  'abrégeant\n',
#  'abrégeas\n',
#  'abrégeasse\n',
#  'abrégeassent\n',
#  'abrégeasses\n',
#  'abrégeassiez\n',
#  'abrégeassions\n',
#  'abrégeâmes\n',
#  'abrégeât\n',
#  'abrégeâtes\n',
#  'abrégent\n',
#  'abrégeons\n',
#  'abréger\n',
#  'abrégera\n',
#  'abrégerai\n',
#  'abrégeraient\n',
#  'abrégerais\n',
#  'abrégerait\n',
#  'abrégeras\n',
#  'abrégerez\n',
#  'abrégeriez\n',
#  'abrégerions\n',
#  'abrégerons\n',
#  'abrégeront\n',
#  'abréges\n',
#  'abrégez\n',
#  'abrégé\n',
#  'abrégée\n',
#  'abrégées\n',
#  'abrégés\n',
#  'abrégèrent\n',
#  'abrégiez\n',
#  'abrégions\n',
#  'abréviatif\n',
#  'abréviatifs\n',
#  'abréviation\n',
#  'abréviations\n',
#  'abréviative\n',
#  'abréviatives\n',
#  'abrègement\n',
#  'abrègements\n',
#  'abri\n',
#  'abricot\n',
#  'abricotier\n',
#  'abricotiers\n',
#  'abricots\n',
#  'abris\n',
#  'abrita\n',
#  'abritai\n',
#  'abritaient\n',
#  'abritais\n',
#  'abritait\n',
#  'abritant\n',
#  'abritas\n',
#  'abritasse\n',
#  'abritassent\n',
#  'abritasses\n',
#  'abritassiez\n',
#  'abritassions\n',
#  'abritâmes\n',
#  'abritât\n',
#  'abritâtes\n',
#  'abrite\n',
#  'abritent\n',
#  'abriter\n',
#  'abritera\n',
#  'abriterai\n',
#  'abriteraient\n',
#  'abriterais\n',
#  'abriterait\n',
#  'abriteras\n',
#  'abriterez\n',
#  'abriteriez\n',
#  'abriterions\n',
#  'abriterons\n',
#  'abriteront\n',
#  'abrites\n',
#  'abritez\n',
#  'abrité\n',
#  'abritée\n',
#  'abritées\n',
#  'abrités\n',
#  'abritèrent\n',
#  'abritiez\n',
#  'abritions\n',
#  'abritons\n',
#  'abrogation\n',
#  'abrogations\n',
#  'abroge\n',
#  'abrogea\n',
#  'abrogeai\n',
#  'abrogeaient\n',
#  'abrogeais\n',
#  'abrogeait\n',
#  'abrogeant\n',
#  'abrogeas\n',
#  'abrogeasse\n',
#  'abrogeassent\n',
#  'abrogeasses\n',
#  'abrogeassiez\n',
#  'abrogeassions\n',
#  'abrogeâmes\n',
#  'abrogeât\n',
#  'abrogeâtes\n',
#  'abrogent\n',
#  'abrogeons\n',
#  'abroger\n',
#  'abrogera\n',
#  'abrogerai\n',
#  'abrogeraient\n',
#  'abrogerais\n',
#  'abrogerait\n',
#  'abrogeras\n',
#  'abrogerez\n',
#  'abrogeriez\n',
#  'abrogerions\n',
#  'abrogerons\n',
#  'abrogeront\n',
#  'abroges\n',
#  'abrogez\n',
#  'abrogé\n',
#  'abrogée\n',
#  'abrogées\n',
#  'abrogés\n',
#  'abrogèrent\n',
#  ...]
